# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import ticker

# %%
final_data = pd.read_csv("./final_data.csv")
final_data['date'] = pd.to_datetime(final_data['date'])
final_data.set_index(['age_group', 'date'], inplace=True)
final_data
# Out:
#                       cum_case  cum_admission  cum_death  cumFirstDose  \
# age_group date
# 00_17     2020-12-08    245465           2556         37             5
# 18_64     2020-12-08   1067064          63561       5485         11812
# 65_84     2020-12-08    168740          83239      28117          3578
# 85+       2020-12-08     71562          42183      22185           765
# 00_17     2020-12-09    249094           2582         38             5
# ...                        ...            ...        ...           ...
# 85+       2021-05-15    142833          83310      46054       1393306
# 00_17     2021-05-16    607230           5675         60         18426
# 18_64     2021-05-16   2842016         141525      11733      19741162
# 65_84     2021-05-16    372874         163902      55078       8938098
# 85+       2021-05-16    142843          83317      46055       1393339
#
#                       newFirstDose  cumSecondDose  newSecondDose  \
# age_group date
# ...

# %%
age_groups = final_data.index.get_level_values('age_group').unique().to_list()
age_groups
# Out:
# ['00_17', '18_64', '65_84', '85+']

# %%
# plot cum_case
plt.rcParams['figure.figsize'] = (9,6)
for age_group in age_groups:
    data = final_data.loc[age_group]['cum_case']
    N_age_group =  final_data.loc[age_group]['population_size'].max()
    plt.plot(data / N_age_group, label=age_group)

plt.gca().yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=1))
plt.grid()
plt.title("Cumulative cases in phase 2")
plt.legend()
plt.show()

# %%
# plot cum_admission
plt.rcParams['figure.figsize'] = (9,6)
for age_group in age_groups:
    data = final_data.loc[age_group]['cum_admission']
    N_age_group =  final_data.loc[age_group]['population_size'].max()
    plt.plot(data / N_age_group, label=age_group)

plt.gca().yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=1))
plt.grid()
plt.title("Cumulative hospitalisations in phase 2")
plt.legend()
plt.show()

# %%
# plot cum_death
plt.rcParams['figure.figsize'] = (9,6)
for age_group in age_groups:
    data = final_data.loc[age_group]['cum_death']
    N_age_group =  final_data.loc[age_group]['population_size'].max()
    plt.plot(data / N_age_group, label=age_group)

plt.gca().yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=1))
plt.grid()
plt.title("Cumulative death in phase 2")
plt.legend()
plt.show()
